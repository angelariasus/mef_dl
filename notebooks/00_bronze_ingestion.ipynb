# %% [markdown]
# # 00 — Ingesta de la Capa Bronze
# ## Extracción de datos crudos (SIAF, SISMEPRE, RENAMU)
#
# Este cuaderno permite ejecutar la extracción de la capa Bronze directamente desde Jupyter, en lugar de hacerlo por terminal.
# Extraerá los datos desde los portales del MEF y los guardará en `data/bronze/`.

# %%
import sys
from pathlib import Path

# Agregar la raíz del proyecto al path de Python
PROJECT_ROOT = Path().resolve().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"Project root: {PROJECT_ROOT}")
print("Paths configurados.")
# Out:
# Project root: /workspace
# Paths configurados.

# %%
from bronze.ingest_bronze import run_pipeline
from src.paths import ensure_dirs

# Asegurarnos de que los directorios existen antes de extraer
ensure_dirs()
print("Módulos importados y directorios listos.")
# Out:
# 2026-06-19 06:05:28 | INFO     | mef_dw.storage.storage_manager | StorageManager iniciado en modo LOCAL
# [OK] Estructura de directorios verificada en /workspace/data
# Módulos importados y directorios listos.

# %% [markdown]
# ### Ejecutar Extracción Histórica (2012 a 2024)
# Esta celda iterará desde 2012 hasta 2024, extrayendo toda la información histórica de la capa Bronze por cada año.
#
# > **Nota:** El sistema es inteligente. Si una fuente ya fue descargada y no ha cambiado en origen, indicará `skipped` (omitido) y pasará a la siguiente sin descargar de nuevo.

# %%
print("Iniciando extracción de la capa Bronze (2012 a 2024)...")
print("-" * 50)

# Extraer explícitamente los años 2012 a 2024
for year in range(2012, 2025):
    print(f"\n--- Procesando año {year} ---")
    results = run_pipeline(year_filter=str(year))
    print(f"Exitosos: {results['successful']} | Omitidos: {results['skipped']} | Fallidos: {results['failed']}")

run_pipeline(source_prefix="sismepre")

print("\nCapa Bronze lista para ser procesada a Silver.")
# Out:
# Iniciando extracción de la capa Bronze (2012 a 2024)...
# --------------------------------------------------
#
# --- Procesando año 2012 ---
# 2026-06-19 06:14:21 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución iniciada | pipeline=bronze_mef id=bc0a8784
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | START - Bronze Pipeline MEF | exec_id=bc0a8784
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:21 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | [SIAF_2012] Procesando...
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | Fuente SIAF_2012 sin cambios (Sun, 12 Oct 2025 13:03:55 GMT), omitiendo.
# 2026-06-19 06:14:21 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | [RENAMU_2012] Procesando...
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | Fuente RENAMU_2012 sin cambios (Thu, 04 May 2023 15:35:48 GMT), omitiendo.
# 2026-06-19 06:14:21 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución terminada | id=bc0a8784 status=SUCCESS duration=0.2s
# 2026-06-19 06:14:21 | INFO     | mef_dw.audit.control_manager | [AUDIT] Reporte guardado: /workspace/data/audit/executions/20260619_061421_bc0a8784_bronze_mef.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | END - Bronze Pipeline MEF | OK=0 SKIP=2 ERR=0
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | ============================================================
# Exitosos: 0 | Omitidos: 2 | Fallidos: 0
#
# --- Procesando año 2013 ---
# 2026-06-19 06:14:21 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución iniciada | pipeline=bronze_mef id=89ad3ff5
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | START - Bronze Pipeline MEF | exec_id=89ad3ff5
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:21 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | [SIAF_2013] Procesando...
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | Fuente SIAF_2013 sin cambios (Sun, 12 Oct 2025 12:54:11 GMT), omitiendo.
# 2026-06-19 06:14:21 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | [RENAMU_2013] Procesando...
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | Fuente RENAMU_2013 sin cambios (Thu, 04 May 2023 15:35:48 GMT), omitiendo.
# 2026-06-19 06:14:21 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución terminada | id=89ad3ff5 status=SUCCESS duration=0.2s
# 2026-06-19 06:14:21 | INFO     | mef_dw.audit.control_manager | [AUDIT] Reporte guardado: /workspace/data/audit/executions/20260619_061421_89ad3ff5_bronze_mef.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | END - Bronze Pipeline MEF | OK=0 SKIP=2 ERR=0
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | ============================================================
# Exitosos: 0 | Omitidos: 2 | Fallidos: 0
#
# --- Procesando año 2014 ---
# 2026-06-19 06:14:21 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución iniciada | pipeline=bronze_mef id=0a53f615
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | START - Bronze Pipeline MEF | exec_id=0a53f615
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:21 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | [SIAF_2014] Procesando...
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | Fuente SIAF_2014 sin cambios (Sun, 12 Oct 2025 19:47:40 GMT), omitiendo.
# 2026-06-19 06:14:21 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | [RENAMU_2014] Procesando...
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | Fuente RENAMU_2014 sin cambios (Thu, 04 May 2023 15:35:49 GMT), omitiendo.
# 2026-06-19 06:14:21 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución terminada | id=0a53f615 status=SUCCESS duration=0.2s
# 2026-06-19 06:14:21 | INFO     | mef_dw.audit.control_manager | [AUDIT] Reporte guardado: /workspace/data/audit/executions/20260619_061421_0a53f615_bronze_mef.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | END - Bronze Pipeline MEF | OK=0 SKIP=2 ERR=0
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | ============================================================
# Exitosos: 0 | Omitidos: 2 | Fallidos: 0
#
# --- Procesando año 2015 ---
# 2026-06-19 06:14:21 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución iniciada | pipeline=bronze_mef id=f298000d
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | START - Bronze Pipeline MEF | exec_id=f298000d
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:21 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:21 | INFO     | mef_dw.ingest_bronze | [SIAF_2015] Procesando...
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | Fuente SIAF_2015 sin cambios (Sun, 12 Oct 2025 12:53:12 GMT), omitiendo.
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | [RENAMU_2015] Procesando...
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | Fuente RENAMU_2015 sin cambios (Thu, 04 May 2023 15:35:50 GMT), omitiendo.
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución terminada | id=f298000d status=SUCCESS duration=0.2s
# 2026-06-19 06:14:22 | INFO     | mef_dw.audit.control_manager | [AUDIT] Reporte guardado: /workspace/data/audit/executions/20260619_061422_f298000d_bronze_mef.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | END - Bronze Pipeline MEF | OK=0 SKIP=2 ERR=0
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# Exitosos: 0 | Omitidos: 2 | Fallidos: 0
#
# --- Procesando año 2016 ---
# 2026-06-19 06:14:22 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución iniciada | pipeline=bronze_mef id=1e99b72d
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | START - Bronze Pipeline MEF | exec_id=1e99b72d
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | [SIAF_2016] Procesando...
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | Fuente SIAF_2016 sin cambios (Sun, 12 Oct 2025 12:55:09 GMT), omitiendo.
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | [RENAMU_2016] Procesando...
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | Fuente RENAMU_2016 sin cambios (Thu, 04 May 2023 15:35:49 GMT), omitiendo.
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución terminada | id=1e99b72d status=SUCCESS duration=0.2s
# 2026-06-19 06:14:22 | INFO     | mef_dw.audit.control_manager | [AUDIT] Reporte guardado: /workspace/data/audit/executions/20260619_061422_1e99b72d_bronze_mef.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | END - Bronze Pipeline MEF | OK=0 SKIP=2 ERR=0
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# Exitosos: 0 | Omitidos: 2 | Fallidos: 0
#
# --- Procesando año 2017 ---
# 2026-06-19 06:14:22 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución iniciada | pipeline=bronze_mef id=b6fe576a
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | START - Bronze Pipeline MEF | exec_id=b6fe576a
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | [SIAF_2017] Procesando...
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | Fuente SIAF_2017 sin cambios (Sun, 12 Oct 2025 12:56:07 GMT), omitiendo.
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | [RENAMU_2017] Procesando...
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | Fuente RENAMU_2017 sin cambios (Thu, 04 May 2023 15:35:50 GMT), omitiendo.
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución terminada | id=b6fe576a status=SUCCESS duration=0.2s
# 2026-06-19 06:14:22 | INFO     | mef_dw.audit.control_manager | [AUDIT] Reporte guardado: /workspace/data/audit/executions/20260619_061422_b6fe576a_bronze_mef.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | END - Bronze Pipeline MEF | OK=0 SKIP=2 ERR=0
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# Exitosos: 0 | Omitidos: 2 | Fallidos: 0
#
# --- Procesando año 2018 ---
# 2026-06-19 06:14:22 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución iniciada | pipeline=bronze_mef id=b69c7356
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | START - Bronze Pipeline MEF | exec_id=b69c7356
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | [SIAF_2018] Procesando...
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | Fuente SIAF_2018 sin cambios (Sun, 12 Oct 2025 13:02:43 GMT), omitiendo.
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | [RENAMU_2018] Procesando...
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | Fuente RENAMU_2018 sin cambios (Thu, 04 May 2023 15:35:50 GMT), omitiendo.
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución terminada | id=b69c7356 status=SUCCESS duration=0.2s
# 2026-06-19 06:14:22 | INFO     | mef_dw.audit.control_manager | [AUDIT] Reporte guardado: /workspace/data/audit/executions/20260619_061422_b69c7356_bronze_mef.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | END - Bronze Pipeline MEF | OK=0 SKIP=2 ERR=0
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# Exitosos: 0 | Omitidos: 2 | Fallidos: 0
#
# --- Procesando año 2019 ---
# 2026-06-19 06:14:22 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución iniciada | pipeline=bronze_mef id=2013e962
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | START - Bronze Pipeline MEF | exec_id=2013e962
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | [SIAF_2019] Procesando...
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | Fuente SIAF_2019 sin cambios (Sun, 12 Oct 2025 12:57:06 GMT), omitiendo.
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | [RENAMU_2019] Procesando...
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | Fuente RENAMU_2019 sin cambios (Wed, 10 May 2023 18:33:31 GMT), omitiendo.
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución terminada | id=2013e962 status=SUCCESS duration=0.2s
# 2026-06-19 06:14:22 | INFO     | mef_dw.audit.control_manager | [AUDIT] Reporte guardado: /workspace/data/audit/executions/20260619_061422_2013e962_bronze_mef.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | END - Bronze Pipeline MEF | OK=0 SKIP=2 ERR=0
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# Exitosos: 0 | Omitidos: 2 | Fallidos: 0
#
# --- Procesando año 2020 ---
# 2026-06-19 06:14:22 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución iniciada | pipeline=bronze_mef id=956bf040
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | START - Bronze Pipeline MEF | exec_id=956bf040
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:22 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:22 | INFO     | mef_dw.ingest_bronze | [SIAF_2020] Procesando...
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | Fuente SIAF_2020 sin cambios (Sun, 12 Oct 2025 12:58:04 GMT), omitiendo.
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | [RENAMU_2020] Procesando...
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | Fuente RENAMU_2020 sin cambios (Thu, 04 May 2023 15:35:51 GMT), omitiendo.
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución terminada | id=956bf040 status=SUCCESS duration=0.2s
# 2026-06-19 06:14:23 | INFO     | mef_dw.audit.control_manager | [AUDIT] Reporte guardado: /workspace/data/audit/executions/20260619_061423_956bf040_bronze_mef.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | END - Bronze Pipeline MEF | OK=0 SKIP=2 ERR=0
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# Exitosos: 0 | Omitidos: 2 | Fallidos: 0
#
# --- Procesando año 2021 ---
# 2026-06-19 06:14:23 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución iniciada | pipeline=bronze_mef id=b53398b0
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | START - Bronze Pipeline MEF | exec_id=b53398b0
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | [SIAF_2021] Procesando...
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | Fuente SIAF_2021 sin cambios (Sun, 12 Oct 2025 12:59:05 GMT), omitiendo.
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | [RENAMU_2021] Procesando...
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | Fuente RENAMU_2021 sin cambios (Thu, 18 May 2023 17:53:47 GMT), omitiendo.
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución terminada | id=b53398b0 status=SUCCESS duration=0.2s
# 2026-06-19 06:14:23 | INFO     | mef_dw.audit.control_manager | [AUDIT] Reporte guardado: /workspace/data/audit/executions/20260619_061423_b53398b0_bronze_mef.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | END - Bronze Pipeline MEF | OK=0 SKIP=2 ERR=0
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# Exitosos: 0 | Omitidos: 2 | Fallidos: 0
#
# --- Procesando año 2022 ---
# 2026-06-19 06:14:23 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución iniciada | pipeline=bronze_mef id=52acb8c8
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | START - Bronze Pipeline MEF | exec_id=52acb8c8
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | [SIAF_2022] Procesando...
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | Fuente SIAF_2022 sin cambios (Sun, 12 Oct 2025 13:12:03 GMT), omitiendo.
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | [RENAMU_2022] Procesando...
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | Fuente RENAMU_2022 sin cambios (Thu, 04 May 2023 15:35:51 GMT), omitiendo.
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución terminada | id=52acb8c8 status=SUCCESS duration=0.2s
# 2026-06-19 06:14:23 | INFO     | mef_dw.audit.control_manager | [AUDIT] Reporte guardado: /workspace/data/audit/executions/20260619_061423_52acb8c8_bronze_mef.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | END - Bronze Pipeline MEF | OK=0 SKIP=2 ERR=0
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# Exitosos: 0 | Omitidos: 2 | Fallidos: 0
#
# --- Procesando año 2023 ---
# 2026-06-19 06:14:23 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución iniciada | pipeline=bronze_mef id=b8656871
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | START - Bronze Pipeline MEF | exec_id=b8656871
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | [SIAF_2023] Procesando...
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | Fuente SIAF_2023 sin cambios (Sun, 12 Oct 2025 12:45:44 GMT), omitiendo.
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | [RENAMU_2023] Procesando...
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | Fuente RENAMU_2023 sin cambios (Wed, 20 Nov 2024 13:49:26 GMT), omitiendo.
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución terminada | id=b8656871 status=SUCCESS duration=0.2s
# 2026-06-19 06:14:23 | INFO     | mef_dw.audit.control_manager | [AUDIT] Reporte guardado: /workspace/data/audit/executions/20260619_061423_b8656871_bronze_mef.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | END - Bronze Pipeline MEF | OK=0 SKIP=2 ERR=0
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# Exitosos: 0 | Omitidos: 2 | Fallidos: 0
#
# --- Procesando año 2024 ---
# 2026-06-19 06:14:23 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución iniciada | pipeline=bronze_mef id=2c27c045
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | START - Bronze Pipeline MEF | exec_id=2c27c045
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | [SIAF_2024] Procesando...
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | Fuente SIAF_2024 sin cambios (Thu, 09 Apr 2026 15:52:13 GMT), omitiendo.
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | [RENAMU_2024] Procesando...
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | Fuente RENAMU_2024 sin cambios (Thu, 06 Feb 2025 11:07:53 GMT), omitiendo.
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución terminada | id=2c27c045 status=SUCCESS duration=0.2s
# 2026-06-19 06:14:23 | INFO     | mef_dw.audit.control_manager | [AUDIT] Reporte guardado: /workspace/data/audit/executions/20260619_061423_2c27c045_bronze_mef.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | END - Bronze Pipeline MEF | OK=0 SKIP=2 ERR=0
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# Exitosos: 0 | Omitidos: 2 | Fallidos: 0
# 2026-06-19 06:14:23 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución iniciada | pipeline=bronze_mef id=bc1ba72e
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | START - Bronze Pipeline MEF | exec_id=bc1ba72e
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:23 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:23 | INFO     | mef_dw.ingest_bronze | [RENTAS_ESAT_ESTADISTICA_ATM] Procesando...
# 2026-06-19 06:14:24 | INFO     | mef_dw.ingest_bronze | Fuente RENTAS_ESAT_ESTADISTICA_ATM sin cambios (unknown), omitiendo.
# 2026-06-19 06:14:24 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:24 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:24 | INFO     | mef_dw.ingest_bronze | [RENTAS_ENTIDAD_ESTADO] Procesando...
# 2026-06-19 06:14:24 | INFO     | mef_dw.ingest_bronze | Fuente RENTAS_ENTIDAD_ESTADO sin cambios (unknown), omitiendo.
# 2026-06-19 06:14:24 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:24 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:24 | INFO     | mef_dw.ingest_bronze | [RENTAS_FORMULARIO] Procesando...
# 2026-06-19 06:14:24 | INFO     | mef_dw.ingest_bronze | Fuente RENTAS_FORMULARIO sin cambios (unknown), omitiendo.
# 2026-06-19 06:14:24 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:24 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:24 | INFO     | mef_dw.ingest_bronze | [RENTAS_PREGUNTAS] Procesando...
# 2026-06-19 06:14:24 | INFO     | mef_dw.ingest_bronze | Fuente RENTAS_PREGUNTAS sin cambios (unknown), omitiendo.
# 2026-06-19 06:14:24 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:24 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:24 | INFO     | mef_dw.ingest_bronze | [RENTAS_ESTADISTICA] Procesando...
# 2026-06-19 06:14:24 | INFO     | mef_dw.ingest_bronze | Fuente RENTAS_ESTADISTICA sin cambios (unknown), omitiendo.
# 2026-06-19 06:14:24 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:24 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:24 | INFO     | mef_dw.ingest_bronze | [RENTAS_RESPUESTAS] Procesando...
# 2026-06-19 06:14:24 | INFO     | mef_dw.ingest_bronze | Fuente RENTAS_RESPUESTAS sin cambios (unknown), omitiendo.
# 2026-06-19 06:14:24 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:24 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:24 | INFO     | mef_dw.ingest_bronze | [RENTAS_ANO_APLICACION] Procesando...
# 2026-06-19 06:14:24 | INFO     | mef_dw.ingest_bronze | Fuente RENTAS_ANO_APLICACION sin cambios (unknown), omitiendo.
# 2026-06-19 06:14:24 | INFO     | mef_dw.storage.storage_manager | Estado leído desde disco: /workspace/data/.state.json
# 2026-06-19 06:14:24 | INFO     | mef_dw.storage.storage_manager | Estado guardado localmente: /workspace/data/.state.json
# 2026-06-19 06:14:24 | INFO     | mef_dw.audit.control_manager | [AUDIT] Ejecución terminada | id=bc1ba72e status=SUCCESS duration=0.7s
# 2026-06-19 06:14:24 | INFO     | mef_dw.audit.control_manager | [AUDIT] Reporte guardado: /workspace/data/audit/executions/20260619_061424_bc1ba72e_bronze_mef.json
# 2026-06-19 06:14:24 | INFO     | mef_dw.ingest_bronze | ============================================================
# 2026-06-19 06:14:24 | INFO     | mef_dw.ingest_bronze | END - Bronze Pipeline MEF | OK=0 SKIP=7 ERR=0
# 2026-06-19 06:14:24 | INFO     | mef_dw.ingest_bronze | ============================================================
#
# Capa Bronze lista para ser procesada a Silver.
